# %%
# import pandas
import pandas as pd

# %%
# load data
df = pd.read_csv("../data/Copy of 76_attributes_heartdiseases.csv")

# %%
df.shape
# Out:
# (282, 76)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 76 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      282 non-null    int64
#  1   V2      282 non-null    int64
#  2   V3      282 non-null    int64
#  3   V4      282 non-null    int64
#  4   V5      282 non-null    int64
#  5   V6      282 non-null    int64
#  6   V7      282 non-null    int64
#  7   V8      282 non-null    int64
#  8   V9      282 non-null    int64
#  9   V10     282 non-null    int64
#  10  V11     282 non-null    int64
#  11  V12     282 non-null    int64
#  12  V13     282 non-null    int64
#  13  V14     282 non-null    int64
#  14  V15     282 non-null    int64
#  15  V16     282 non-null    int64
#  16  V17     282 non-null    int64
#  17  V18     282 non-null    int64
#  18  V19     282 non-null    int64
#  19  V20     282 non-null    int64
#  20  V21     282 non-null    int64
#  21  V22     282 non-null    int64
# ...

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# finding unique values
df.nunique()
# Out:
# V1     282
# V2       1
# V3      41
# V4       2
# V5       1
# V6       1
# V7       2
# V8       3
# V9       6
# V10     49
# V11      5
# V12    145
# V13      4
# V14     23
# V15     38
# V16      3
# V17      2
# V18      2
# V19      5
# V20     14
# V21     33
# V22      5
# V23      3
# V24      3
# V25      3
# V26      3
# V27      3
# V28      4
# V29     65
# V30     35
# V31     20
# V32     93
# V33     63
# V34     60
# V35     42
# V36     50
# V37     31
# V38      2
# V39      6
# V40     39
# V41      4
# V42      5
# V43    117
# V44      5
# V45      1
# V46      1
# V47      1
# V48      1
# V49      1
# V50      3
# V51      4
# V52      1
# V53      1
# V54      5
# V55     15
# V56     33
# V57      6
# V58      5
# V59      2
# V60      2
# V61      3
# V62      2
# V63      5
# V64      3
# V65      3
# V66      3
# V67      2
# V68      2
# V69      1
# V70      2
# V71      7
# V72      7
# V73      5
# V74      1
# V75      2
# V76      1
# ...

# %%
cat_col = df.columns[df.nunique() < 10]

# %%
cont_col = df.columns[df.nunique() >= 10]

# %%
cat_col
# Out:
# Index(['V2', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V11', 'V13', 'V16', 'V17',
#        'V18', 'V19', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V38',
#        'V39', 'V41', 'V42', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50',
#        'V51', 'V52', 'V53', 'V54', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62',
#        'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72',
#        'V73', 'V74', 'V75', 'V76'],
#       dtype='object')

# %%
cont_col
# Out:
# Index(['V1', 'V3', 'V10', 'V12', 'V14', 'V15', 'V20', 'V21', 'V29', 'V30',
#        'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V40', 'V43', 'V55',
#        'V56'],
#       dtype='object')

# %%
# In this data -9 represents missing value
df = pd.read_csv("./data/Copy of 76_attributes_heartdiseases.csv",
                 na_values=[-9,'-9',-18])

# %%
df.describe()
# Out:
#                V1     V2          V3          V4   V5   V6   V7        V8  \
# count  282.000000  282.0  282.000000  282.000000  0.0  0.0  0.0  3.000000
# mean   151.517730    0.0   54.411348    0.677305  NaN  NaN  NaN  3.333333
# std     87.131234    0.0    9.053083    0.468338  NaN  NaN  NaN  0.577350
# min      1.000000    0.0   29.000000    0.000000  NaN  NaN  NaN  3.000000
# 25%     75.250000    0.0   48.000000    0.000000  NaN  NaN  NaN  3.000000
# 50%    151.500000    0.0   55.000000    1.000000  NaN  NaN  NaN  3.000000
# 75%    227.750000    0.0   61.000000    1.000000  NaN  NaN  NaN  3.500000
# max    298.000000    0.0   77.000000    1.000000  NaN  NaN  NaN  4.000000
#
#                V9         V10         V11         V12        V13         V14  \
# count  282.000000  282.000000  282.000000  279.000000   3.000000  277.000000
# mean     4.432624  130.269504    2.822695  249.530466  16.666667   16.956679
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 76 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      282 non-null    int64
#  1   V2      282 non-null    int64
#  2   V3      282 non-null    int64
#  3   V4      282 non-null    int64
#  4   V5      0 non-null      float64
#  5   V6      0 non-null      float64
#  6   V7      0 non-null      float64
#  7   V8      3 non-null      float64
#  8   V9      282 non-null    int64
#  9   V10     282 non-null    int64
#  10  V11     282 non-null    int64
#  11  V12     279 non-null    float64
#  12  V13     3 non-null      float64
#  13  V14     277 non-null    float64
#  14  V15     277 non-null    float64
#  15  V16     279 non-null    float64
#  16  V17     26 non-null     float64
#  17  V18     282 non-null    int64
#  18  V19     282 non-null    int64
#  19  V20     282 non-null    int64
#  20  V21     282 non-null    int64
# ...

# %%
df.isna().sum()/df.shape[0] *100
# Out:
# V1       0.000000
# V2       0.000000
# V3       0.000000
# V4       0.000000
# V5     100.000000
# V6     100.000000
# V7     100.000000
# V8      98.936170
# V9       0.000000
# V10      0.000000
# V11      0.000000
# V12      1.063830
# V13     98.936170
# V14      1.773050
# V15      1.773050
# V16      1.063830
# V17     90.780142
# V18      0.000000
# V19      0.000000
# V20      0.000000
# V21      0.000000
# V22      0.000000
# V23      0.709220
# V24      0.709220
# V25      0.709220
# V26      0.709220
# V27      0.709220
# V28      0.000000
# V29      0.000000
# V30     24.468085
# V31      0.000000
# V32      0.000000
# V33      0.000000
# V34      0.000000
# V35      0.000000
# V36      0.000000
# V37      0.000000
# V38      0.000000
# V39      0.000000
# V40      0.000000
# V41      1.418440
# V42     98.581560
# V43      0.000000
# V44      2.127660
# V45    100.000000
# V46    100.000000
# V47    100.000000
# V48    100.000000
# V49    100.000000
# V50     98.581560
# ...

# %%
df.columns[(df.isna().sum()/df.shape[0] *100) > 90]
# Out:
# Index(['V5', 'V6', 'V7', 'V8', 'V13', 'V17', 'V42', 'V45', 'V46', 'V47', 'V48',
#        'V49', 'V50', 'V52', 'V53', 'V54', 'V62', 'V64', 'V66', 'V74', 'V75'],
#       dtype='object')

# %%
drop_col = df.columns[(df.isna().sum()/df.shape[0] *100) > 90]

# %%
df.shape
# Out:
# (282, 76)

# %%
df.drop(drop_col, axis=1,inplace=True)

# %%
df.shape
# Out:
# (282, 55)

# %%
drop_col= df.columns[df.nunique() == 1]

# %%
df.drop(drop_col, axis=1,inplace=True)

# %%
df.shape
# Out:
# (282, 52)

# %%
# We are dropping V1 columns
# because it is identity column
df.drop('V1', axis=1,inplace=True)

# %%
df.shape
# Out:
# (282, 51)

# %%
valid_col = df.columns

# %%
valid_col
# Out:
# Index(['V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#        'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38',
#        'V39', 'V40', 'V41', 'V43', 'V44', 'V51', 'V55', 'V56', 'V57', 'V58',
#        'V59', 'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V70', 'V71', 'V72',
#        'V73'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (282, 51)

# %%
df_1 = df.select_dtypes(exclude = 'object')

# %%
df_1.shape
# Out:
# (282, 50)

# %%
df_2 = df.select_dtypes(include = 'object')

# %%
df_2.columns
# Out:
# Index(['V63'], dtype='object')

# %%
df_2['V63'].unique() # we decide to drop column
# Out:
# array(['1', '2', nan, '9-Jan', '1-Jan'], dtype=object)

# %%
# drop V63 from original data
df.drop('V63',axis=1,inplace=True)

# %%
df.shape
# Out:
# (282, 50)

# %%
df.select_dtypes(include = 'object').shape
# Out:
# (282, 0)

# %%
cat_col = df.columns[(df.nunique() < 10)]

# %%
cont_col = df.columns[(df.nunique() >= 10)]

# %%
cat_col
# Out:
# Index(['V4', 'V9', 'V11', 'V16', 'V18', 'V19', 'V22', 'V23', 'V24', 'V25',
#        'V26', 'V27', 'V28', 'V38', 'V39', 'V41', 'V44', 'V51', 'V57', 'V58',
#        'V59', 'V60', 'V61', 'V65', 'V67', 'V68', 'V70', 'V71', 'V72', 'V73'],
#       dtype='object')

# %%
df.loc[:,cat_col] = df.loc[:,cat_col].fillna(df.loc[:,cat_col].mode().iloc[0])

# %%
df.loc[:,cont_col] = df.loc[:,cont_col].fillna(df.loc[:,cont_col].median())

# %%
df.isna().sum()
# Out:
# V3     0
# V4     0
# V9     0
# V10    0
# V11    0
# V12    0
# V14    0
# V15    0
# V16    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# V41    0
# V43    0
# V44    0
# V51    0
# V55    0
# V56    0
# V57    0
# V58    0
# V59    0
# V60    0
# V61    0
# V65    0
# V67    0
# V68    0
# V70    0
# V71    0
# V72    0
# V73    0
# dtype: int64

# %%
# appplying formula for standardization (x-mew)/std

# %%
df.loc[:,cont_col] = (df.loc[:,cont_col] - df.loc[:,cont_col].mean()) / df.loc[:,cont_col].std()
# Out:
# /var/folders/54/gfhqd5h505l__hz49w789hjr0000gn/T/ipykernel_47439/1231680150.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.94869923  1.39053768  1.39053768 -1.9232507  -1.48141225  0.17548194
#   0.83823961  0.28594155  0.94869923 -0.1558969   0.28594155  0.17548194
#   0.17548194 -1.15003341 -0.26635651  0.28594155 -0.70819496 -0.04543729
#  -0.70819496 -0.59773535  1.05915884  0.39640116  0.39640116  0.39640116
#   0.61732039 -0.48727574  0.39640116  1.28007806 -1.26049303 -1.59187187
#   1.6114569   0.61732039  1.05915884  0.50686078 -1.15003341 -1.37095264
#  -1.26049303  0.28594155  0.06502233  0.72778     1.16961845 -1.59187187
#   1.83237613  0.50686078  0.72778     0.39640116 -0.37681613 -0.48727574
#   1.16961845 -0.1558969  -1.48141225  1.16961845 -1.15003341 -1.15003341
#   0.61732039 -0.04543729 -0.48727574 -1.48141225 -0.04543729 -0.37681613
# ...

# %%
df.loc[:,cont_col].mean()
# Out:
# V3    -1.354315e-16
# V10    1.763759e-16
# V12   -6.299138e-18
# V14    1.007862e-16
# V15    3.779483e-17
# V20   -1.259828e-17
# V21   -7.558965e-17
# V29   -1.070853e-16
# V30   -5.039310e-17
# V31    6.299138e-17
# V32   -2.519655e-17
# V33   -3.779483e-17
# V34   -3.622004e-16
# V35    8.818793e-17
# V36   -2.283437e-16
# V37    4.409396e-17
# V40    2.393672e-16
# V43    8.818793e-17
# V55    5.669224e-17
# V56   -6.299138e-18
# dtype: float64

# %%
# Descriptive analysisis
df.describe()
# Out:
#                  V3          V4          V9           V10         V11  \
# count  2.820000e+02  282.000000  282.000000  2.820000e+02  282.000000
# mean  -1.354315e-16    0.677305    4.432624  1.763759e-16    2.822695
# std    1.000000e+00    0.468338   12.365608  1.000000e+00   21.932859
# min   -2.806928e+00    0.000000    1.000000 -5.818174e+00    0.000000
# 25%   -7.081950e-01    0.000000    3.000000 -4.622108e-01    0.000000
# 50%    6.502233e-02    1.000000    3.000000 -1.212984e-02    1.000000
# 75%    7.277800e-01    1.000000    4.000000  4.379511e-01    1.000000
# max    2.495134e+00    1.000000  130.000000  3.138437e+00  253.000000
#
#                 V12           V14           V15         V16         V18  \
# count  2.820000e+02  2.820000e+02  2.820000e+02  282.000000  282.000000
# mean  -6.299138e-18  1.007862e-16  3.779483e-17    0.148936    0.609929
# std    1.000000e+00  1.000000e+00  1.000000e+00    0.356658    0.488633
# ...
